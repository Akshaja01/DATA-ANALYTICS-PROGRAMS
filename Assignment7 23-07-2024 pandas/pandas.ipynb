# %%
pip install pandas
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df1=pd.read_csv('titanic.csv')

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### a print 6 rows

# %%
df1.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# ### print summary

# %%
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ###  count null values

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Average people survived

# %%
df1['Survived'].mean()
# Out:
# np.float64(0.3838383838383838)

# %% [markdown]
# ### Average of male and female survived

# %%
df1.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# ### Dataframe based on Gender Pclass

# %%
df1.groupby(['Sex','Pclass']).size()
# Out:
# Sex     Pclass
# female  1          94
#         2          76
#         3         144
# male    1         122
#         2         108
#         3         347
# dtype: int64

# %% [markdown]
# ### Program to read a dataset from weather file

# %%
pip install pandas
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df2=pd.read_csv('weather.csv')

# %%
df2
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# ### print the first 6 rows

# %%
df2.head(6)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
# 5      6.2     16.9       0.0          5.8       8.2          SE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
# 5           44.0         SE          E          20.0  ...           57
#
# ...

# %% [markdown]
# ### summary

# %%
df2.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %% [markdown]
# ### count of null values

# %%
df2.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %% [markdown]
# ### Maximum temperature

# %%
df2['MaxTemp'].idxmax
# Out:
# <bound method Series.idxmax of 0      24.3
# 1      26.9
# 2      23.4
# 3      15.5
# 4      16.1
#        ...
# 361    30.7
# 362    28.4
# 363    19.9
# 364    26.9
# 365    30.2
# Name: MaxTemp, Length: 366, dtype: float64>

# %% [markdown]
# ### Average windspeed

# %%
df2[['WindGustSpeed']].mean()
# Out:
# WindGustSpeed    39.840659
# dtype: float64

# %%
import pandas as pd

# %%
df2=pd.read_csv('weather.csv')

# %% [markdown]
# ### Numeric mean

# %%
df2[['MinTemp','MaxTemp','Rainfall','Evaporation','Sunshine','WindGustSpeed','WindSpeed9am','WindSpeed3pm','Humidity9am','Humidity3pm','Pressure9am','Pressure3pm','Cloud9am','Cloud3pm','Temp9am','Temp3pm','RISK_MM']].mean()
# Out:
# MinTemp             7.265574
# MaxTemp            20.550273
# Rainfall            1.428415
# Evaporation         4.521858
# Sunshine            7.909366
# WindGustSpeed      39.840659
# WindSpeed9am        9.651811
# WindSpeed3pm       17.986339
# Humidity9am        72.035519
# Humidity3pm        44.519126
# Pressure9am      1019.709016
# Pressure3pm      1016.810383
# Cloud9am            3.890710
# Cloud3pm            4.024590
# Temp9am            12.358470
# Temp3pm            19.230874
# RISK_MM             1.428415
# dtype: float64

# %% [markdown]
# ### Make new dataframe contains minimum values

# %%
df2_new=pd.DataFrame()
print(df2_new)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df2_new=df2.select_dtypes('number').min()
df2_new
# Out:
# MinTemp           -5.3
# MaxTemp            7.6
# Rainfall           0.0
# Evaporation        0.2
# Sunshine           0.0
# WindGustSpeed     13.0
# WindSpeed9am       0.0
# WindSpeed3pm       0.0
# Humidity9am       36.0
# Humidity3pm       13.0
# Pressure9am      996.5
# Pressure3pm      996.8
# Cloud9am           0.0
# Cloud3pm           0.0
# Temp9am            0.1
# Temp3pm            5.1
# RISK_MM            0.0
# dtype: float64

# %% [markdown]
# ### New Dataframe on temperature

# %%
df2_new1=pd.DataFrame()
print(df2_new1)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df2_new1=df2['MinTemp']
df2_new1
# Out:
# 0       8.0
# 1      14.0
# 2      13.7
# 3      13.3
# 4       7.6
#        ...
# 361     9.0
# 362     7.1
# 363    12.5
# 364    12.5
# 365    12.3
# Name: MinTemp, Length: 366, dtype: float64

# %% [markdown]
# ### Diamonds

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df3=pd.read_csv('diamonds.csv')

# %%
df3
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %% [markdown]
# ### first 6 rows

# %%
df3.head(6)
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1           2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2           3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3           4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4           5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
#
#       y     z
# 0  3.98  2.43
# 1  3.84  2.31
# 2  4.07  2.31
# 3  4.23  2.63
# 4  4.35  2.75
# 5  3.96  2.48

# %% [markdown]
# ### summary

# %%
df3.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %% [markdown]
# ### mean of numeric

# %%
df3.select_dtypes('number').mean()
# Out:
# Unnamed: 0    26970.500000
# carat             0.797940
# depth            61.749405
# table            57.457184
# price          3932.799722
# x                 5.731157
# y                 5.734526
# z                 3.538734
# dtype: float64

# %% [markdown]
# ### count null values

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %% [markdown]
# ### duplicate

# %%
df3.duplicated().sum()
# Out:
# np.int64(0)

# %%
import pandas as pd

# %%
df3=pd.read_csv('diamonds.csv')

# %% [markdown]
# ### min price

# %%
df3.groupby('cut')['price'].min()
# Out:
# cut
# Fair         337
# Good         327
# Ideal        326
# Premium      326
# Very Good    336
# Name: price, dtype: int64

# %% [markdown]
# ### max price

# %%
df3.groupby('cut')['price'].max()
# Out:
# cut
# Fair         18574
# Good         18788
# Ideal        18806
# Premium      18823
# Very Good    18818
# Name: price, dtype: int64

# %% [markdown]
# ### Sales

# %%
df4=pd.read_csv('sales.csv')

# %%
df4
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %% [markdown]
# ### Total profit of all months and line graph

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/165.9 kB 435.7 kB/s eta 0:00:01
#      ------------------ ------------------ 81.9/165.9 kB 762.6 kB/s eta 0:00:01
#      -------------------------------------- 165.9/165.9 kB 1.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.0 MB 6.0 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/8.0 MB 5.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/8.0 MB 6.8 MB/s eta 0:00:02
#    ------- -------------------------------- 1.4/8.0 MB 7.6 MB/s eta 0:00:01
#    --------- ------------------------------ 1.8/8.0 MB 7.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.3/8.0 MB 8.1 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
line1=pd.read_csv('sales.csv')

# %%
line1.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
line1.plot(x='month_number',y='total_profit',kind='line',title='Total profit',grid='true',xlabel='months',ylabel='total profits')
# Out:
# <Axes: title={'center': 'Total profit'}, xlabel='months', ylabel='total profits'>

# %%
line1.plot(xlabel='month_number',ylabel='total_profit')
# Out:
# <Axes: xlabel='month_number', ylabel='total_profit'>

# %%
plt.scatter(line1['month_number'],line1['toothpaste'],color='r')

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
line1=pd.read_csv('sales.csv')

# %%
line1.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
plt.bar(line1.month_number,line1.bathingsoap,color='g')
# Out:
# <BarContainer object of 12 artists>

# %%
products=['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']
total_sales=line1[products].sum()
plt.pie(total_sales,labels=products)
plt.show()

# %% [markdown]
# ### Alcohol

# %%
import pandas as pd

# %%
df=pd.read_csv('world_alcohol.csv')

# %%
df
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %% [markdown]
# ### display dimension or shape

# %%
(df.shape)
# Out:
# (100, 5)

# %%
(df.columns)
# Out:
# Index(['Year', 'WHO region', 'Country', 'Beverage Types', 'Display Value'], dtype='object')

# %%
import pandas as pd

# %%
df=pd.read_csv('world_alcohol.csv')

# %% [markdown]
# ### drop missing values

# %%
df.drop_duplicates('WHO region')
# Out:
#     Year             WHO region       Country Beverage Types  Display Value
# 0   1986        Western Pacific      Viet Nam           Wine           0.00
# 1   1986               Americas       Uruguay          Other           0.50
# 2   1985                 Africa  Cte d'Ivoire           Wine           1.62
# 13  1984  Eastern Mediterranean   Afghanistan          Other           0.00
# 18  1984                 Europe        Norway        Spirits           1.62
# 20  1986        South-East Asia       Myanmar           Wine           0.00

# %% [markdown]
# ### Alcohol consumption

# %%
df[(df['Year']==1987)|(df['Year']==1989)]
# Out:
#     Year             WHO region                           Country  \
# 4   1987               Americas             Saint Kitts and Nevis
# 5   1987               Americas                         Guatemala
# 6   1987                 Africa                         Mauritius
# 10  1987                 Africa                          Botswana
# 11  1989               Americas                         Guatemala
# 15  1987                 Africa                     Guinea-Bissau
# 17  1989                 Africa                        Seychelles
# 21  1989               Americas                        Costa Rica
# 28  1987        Western Pacific                          Viet Nam
# 32  1989                 Africa                         Mauritius
# 36  1987  Eastern Mediterranean                             Egypt
# 38  1987  Eastern Mediterranean                             Qatar
# 39  1987                 Africa                      Burkina Faso
# ...

# %% [markdown]
# ### Alcohol consumption in America

# %%
df[df['Year']==1985]
# Out:
#     Year             WHO region  \
# 2   1985                 Africa
# 7   1985                 Africa
# 12  1985        Western Pacific
# 14  1985        Western Pacific
# 24  1985                 Africa
# 26  1985                 Europe
# 33  1985                 Africa
# 35  1985               Americas
# 44  1985                 Europe
# 50  1985                 Europe
# 63  1985  Eastern Mediterranean
# 71  1985                 Africa
# 76  1985                 Africa
# 77  1985                 Africa
# 80  1985                 Africa
# 81  1985                 Europe
# 85  1985                 Africa
# 94  1985                 Europe
# 96  1985                 Europe
# 99  1985        South-East Asia
#
#                                               Country Beverage Types  \
# 2                                        Cte d'Ivoire           Wine
# 7                                              Angola        Spirits
# ...

# %% [markdown]
# ### Filter reords where WHO region matches

# %%
df[(df['WHO region']=="Africa")|(df['WHO region']=="Eastern Mediterranean")|(df['WHO region']=="Europe")]
# Out:
#     Year WHO region            Country Beverage Types  Display Value
# 2   1985     Africa       Cte d'Ivoire           Wine           1.62
# 6   1987     Africa          Mauritius           Wine           0.13
# 7   1985     Africa             Angola        Spirits           0.39
# 9   1984     Africa            Nigeria          Other           6.10
# 10  1987     Africa           Botswana           Wine           0.20
# ..   ...        ...                ...            ...            ...
# 93  1987     Africa         Madagascar          Other            NaN
# 94  1985     Europe            Ukraine        Spirits           3.06
# 95  1984     Africa              Niger          Other           0.00
# 96  1985     Europe         Luxembourg           Wine           7.38
# 98  1984     Africa  Equatorial Guinea           Wine           0.00
#
# [69 rows x 5 columns]

# %% [markdown]
# ### Pandas program to join

# %%
concat1=pd.concat([df2,df3],axis=0)
concat1
# Out:
#        MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0          8.0     24.3       0.0          3.4       6.3          NW
# 1         14.0     26.9       3.6          4.4       9.7         ENE
# 2         13.7     23.4       3.6          5.8       3.3          NW
# 3         13.3     15.5      39.8          7.2       9.1          NW
# 4          7.6     16.1       2.8          5.6      10.6         SSE
# ...        ...      ...       ...          ...       ...         ...
# 53935      NaN      NaN       NaN          NaN       NaN         NaN
# 53936      NaN      NaN       NaN          NaN       NaN         NaN
# 53937      NaN      NaN       NaN          NaN       NaN         NaN
# 53938      NaN      NaN       NaN          NaN       NaN         NaN
# 53939      NaN      NaN       NaN          NaN       NaN         NaN
#
#        WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  carat  \
# ...

# %% [markdown]
# ### Join the two dataframes along columns

# %%
concat2=pd.concat([df2,df3],axis=1)
concat2
# Out:
#        MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0          8.0     24.3       0.0          3.4       6.3          NW
# 1         14.0     26.9       3.6          4.4       9.7         ENE
# 2         13.7     23.4       3.6          5.8       3.3          NW
# 3         13.3     15.5      39.8          7.2       9.1          NW
# 4          7.6     16.1       2.8          5.6      10.6         SSE
# ...        ...      ...       ...          ...       ...         ...
# 53935      NaN      NaN       NaN          NaN       NaN         NaN
# 53936      NaN      NaN       NaN          NaN       NaN         NaN
# 53937      NaN      NaN       NaN          NaN       NaN         NaN
# 53938      NaN      NaN       NaN          NaN       NaN         NaN
# 53939      NaN      NaN       NaN          NaN       NaN         NaN
#
#        WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  carat  \
# ...
